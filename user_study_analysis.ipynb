# %%
import pandas as pd
import json
from datetime import datetime

df = pd.read_csv('data/user_study/user_study_results.csv', index_col="What is your tester ID? (Given to you by instructor)")

# %%
df = df.drop(["Zeitstempel", "Prerequisites to be checked by instructor", "After the test (to be done by instructor)", "For the instructor: Start the 45 minute timer now!"], axis=1)
df.head()
# Out:
#                                                    How many years of experience do you have working with Kubernetes?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 3-5
# 3                                                                                                 3-5
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with Angular?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How often do you use AI-assisted IDEs for coding?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                       frequently/about once a week
# 2                                                                             all the time/every day
# 3                                                                             all the time/every day
# 4                                                                       frequently/about once a week
# 5                                                                       frequently/about once a week
#
#                                                                        Please answer these questions.  \
# What is your tester ID? (Given to you by instru...
# 1                                                   Building the project in the CI/CD pipeline run...
# 2                                                   CI/CD pipelines run on every commit, The "test...
# 3                                                   CI/CD pipelines run on every commit, The "test...
# 4                                                   CI/CD pipelines run on every commit, The "test...
# 5                                                                 CI/CD pipelines run on every commit
#
#                                                    How was you experience deploying software using the AI-assisted IDE?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 bad
# 2                                                                                                good
# 3                                                                                                fair
# 4                                                                                                good
# 5                                                                                                 bad
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40

# %%
df["cicd_runs_on_commit"] = df["Please answer these questions."].str.contains("CI/CD pipelines run on every commit", na=False)
df["test_stage_works"] = df["Please answer these questions."].str.contains("The \"test\"-stage in the CI/CD pipeline runs without error", na=False)
df["build_stage_works"] = df["Please answer these questions."].str.contains("Building the project in the CI/CD pipeline runs without error", na=False)
df["docker_image_push_works"] = df["Please answer these questions."].str.contains("Docker image is successfully pushed to the registry", na=False)
df["deploy_stage_works"] = df["Please answer these questions."].str.contains("The \"deploy\"-stage in the CI/CD pipeline runs without error", na=False)
df["k8s_deploy_works"] = df["Please answer these questions."].str.contains("The deployment itself worked, pods on Kubernetes are in state \"Running\"", na=False)
df["pod_log_error_free"] = df["Please answer these questions."].str.contains("The pod logs don't indicate an error", na=False)

df = df.drop("Please answer these questions.", axis=1)

df.head()
# Out:
#                                                    How many years of experience do you have working with Kubernetes?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 3-5
# 3                                                                                                 3-5
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with Angular?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How often do you use AI-assisted IDEs for coding?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                       frequently/about once a week
# 2                                                                             all the time/every day
# 3                                                                             all the time/every day
# 4                                                                       frequently/about once a week
# 5                                                                       frequently/about once a week
#
#                                                    How was you experience deploying software using the AI-assisted IDE?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 bad
# 2                                                                                                good
# 3                                                                                                fair
# 4                                                                                                good
# 5                                                                                                 bad
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     deploy_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                 True
# 4                                                                 True
# 5                                                                False
#
#                                                     k8s_deploy_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                              False
# 4                                                               True
# 5                                                              False
#
#                                                     pod_log_error_free
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                False
# 4                                                                 True
# 5                                                                False

# %%
df["experience_excellent"] = df["How was you experience deploying software using the AI-assisted IDE?"].str.contains("excellent", na=False)
df["experience_good"] = df["How was you experience deploying software using the AI-assisted IDE?"].str.contains("good", na=False)
df["experience_fair"] = df["How was you experience deploying software using the AI-assisted IDE?"].str.contains("fair", na=False)
df["experience_poor"] = df["How was you experience deploying software using the AI-assisted IDE?"].str.contains("poor", na=False)
df["experience_bad"] = df["How was you experience deploying software using the AI-assisted IDE?"].str.contains("bad", na=False)

df = df.drop("How was you experience deploying software using the AI-assisted IDE?", axis=1)

df.head()
# Out:
#                                                    How many years of experience do you have working with Kubernetes?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 3-5
# 3                                                                                                 3-5
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with Angular?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How often do you use AI-assisted IDEs for coding?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                       frequently/about once a week
# 2                                                                             all the time/every day
# 3                                                                             all the time/every day
# 4                                                                       frequently/about once a week
# 5                                                                       frequently/about once a week
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     deploy_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                 True
# 4                                                                 True
# 5                                                                False
#
#                                                     k8s_deploy_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                              False
# 4                                                               True
# 5                                                              False
#
#                                                     pod_log_error_free  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                False
# 4                                                                 True
# 5                                                                False
#
#                                                     experience_excellent  \
# What is your tester ID? (Given to you by instru...
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# 5                                                                  False
#
#                                                     experience_good  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                              True
# 3                                                             False
# 4                                                              True
# 5                                                             False
#
#                                                     experience_fair  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                             False
# 3                                                              True
# 4                                                             False
# 5                                                             False
#
#                                                     experience_poor  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                             False
# 3                                                             False
# 4                                                             False
# 5                                                             False
#
#                                                     experience_bad
# What is your tester ID? (Given to you by instru...
# 1                                                             True
# 2                                                            False
# 3                                                            False
# 4                                                            False
# 5                                                             True

# %%
df["use_never"] = df["How often do you use AI-assisted IDEs for coding?"].str.contains("never", na=False)
df["use_not_often"] = df["How often do you use AI-assisted IDEs for coding?"].str.contains("not often/maybe once a month", na=False)
df["use_frequently"] = df["How often do you use AI-assisted IDEs for coding?"].str.contains("frequently/about once a week", na=False)
df["use_all_the_time"] = df["How often do you use AI-assisted IDEs for coding?"].str.contains("all the time/every day", na=False)

df = df.drop("How often do you use AI-assisted IDEs for coding?", axis=1)

df.head()
# Out:
#                                                    How many years of experience do you have working with Kubernetes?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 3-5
# 3                                                                                                 3-5
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with Angular?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  ...  \
# What is your tester ID? (Given to you by instru...                     ...
# 1                                                                True  ...
# 2                                                                True  ...
# 3                                                                True  ...
# 4                                                                True  ...
# 5                                                               False  ...
#
#                                                     pod_log_error_free  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                False
# 4                                                                 True
# 5                                                                False
#
#                                                     experience_excellent  \
# What is your tester ID? (Given to you by instru...
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# 5                                                                  False
#
#                                                     experience_good  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                              True
# 3                                                             False
# 4                                                              True
# 5                                                             False
#
#                                                     experience_fair  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                             False
# 3                                                              True
# 4                                                             False
# 5                                                             False
#
#                                                     experience_poor  \
# What is your tester ID? (Given to you by instru...
# 1                                                             False
# 2                                                             False
# 3                                                             False
# 4                                                             False
# 5                                                             False
#
#                                                     experience_bad  use_never  \
# What is your tester ID? (Given to you by instru...
# 1                                                             True      False
# 2                                                            False      False
# 3                                                            False      False
# 4                                                            False      False
# 5                                                             True      False
#
#                                                     use_not_often  \
# What is your tester ID? (Given to you by instru...
# 1                                                           False
# 2                                                           False
# 3                                                           False
# 4                                                           False
# 5                                                           False
#
#                                                     use_frequently  \
# What is your tester ID? (Given to you by instru...
# 1                                                             True
# 2                                                            False
# 3                                                            False
# 4                                                             True
# 5                                                             True
#
#                                                     use_all_the_time
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                              False
# 5                                                              False
#
# [5 rows x 23 columns]

# %%
df["kubernetes_0_1"] = df["How many years of experience do you have working with Kubernetes?"].str.contains("0-1", na=False)
df["kubernetes_1_2"] = df["How many years of experience do you have working with Kubernetes?"].str.contains("1-2", na=False)
df["kubernetes_3_5"] = df["How many years of experience do you have working with Kubernetes?"].str.contains("3-5", na=False)
df["kubernetes_5+"] = df["How many years of experience do you have working with Kubernetes?"].str.contains("5+", na=False)

df = df.drop("How many years of experience do you have working with Kubernetes?", axis=1)

df.head()
# Out:
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with Angular?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     ...  experience_poor  \
# What is your tester ID? (Given to you by instru...  ...
# 1                                                   ...            False
# 2                                                   ...            False
# 3                                                   ...            False
# 4                                                   ...            False
# 5                                                   ...            False
#
#                                                     experience_bad  use_never  \
# What is your tester ID? (Given to you by instru...
# 1                                                             True      False
# 2                                                            False      False
# 3                                                            False      False
# 4                                                            False      False
# 5                                                             True      False
#
#                                                     use_not_often  \
# What is your tester ID? (Given to you by instru...
# 1                                                           False
# 2                                                           False
# 3                                                           False
# 4                                                           False
# 5                                                           False
#
#                                                     use_frequently  \
# What is your tester ID? (Given to you by instru...
# 1                                                             True
# 2                                                            False
# 3                                                            False
# 4                                                             True
# 5                                                             True
#
#                                                     use_all_the_time  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                              False
# 5                                                              False
#
#                                                     kubernetes_0_1  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                            False
# 3                                                            False
# 4                                                             True
# 5                                                             True
#
#                                                     kubernetes_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                            False
# 3                                                            False
# 4                                                            False
# 5                                                            False
#
#                                                     kubernetes_3_5  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                             True
# 3                                                             True
# 4                                                            False
# 5                                                            False
#
#                                                     kubernetes_5+
# What is your tester ID? (Given to you by instru...
# 1                                                            True
# 2                                                            True
# 3                                                            True
# 4                                                           False
# 5                                                           False
#
# [5 rows x 26 columns]

# %%
df["angular_0_1"] = df["How many years of experience of you have working with Angular?"].str.contains("0-1", na=False)
df["angular_1_2"] = df["How many years of experience of you have working with Angular?"].str.contains("1-2", na=False)
df["angular_3_5"] = df["How many years of experience of you have working with Angular?"].str.contains("3-5", na=False)
df["angular_5+"] = df["How many years of experience of you have working with Angular?"].str.contains("5+", na=False)

df = df.drop("How many years of experience of you have working with Angular?", axis=1)

df.head()
# Out:
#                                                    How many years of experience do you have working with CI/CD pipelines?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                  5+
# 2                                                                                                 1-2
# 3                                                                                                 1-2
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     deploy_stage_works  ...  \
# What is your tester ID? (Given to you by instru...                      ...
# 1                                                                False  ...
# 2                                                                 True  ...
# 3                                                                 True  ...
# 4                                                                 True  ...
# 5                                                                False  ...
#
#                                                     use_frequently  \
# What is your tester ID? (Given to you by instru...
# 1                                                             True
# 2                                                            False
# 3                                                            False
# 4                                                             True
# 5                                                             True
#
#                                                     use_all_the_time  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                              False
# 5                                                              False
#
#                                                     kubernetes_0_1  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                            False
# 3                                                            False
# 4                                                             True
# 5                                                             True
#
#                                                     kubernetes_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                            False
# 3                                                            False
# 4                                                            False
# 5                                                            False
#
#                                                     kubernetes_3_5  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                             True
# 3                                                             True
# 4                                                            False
# 5                                                            False
#
#                                                     kubernetes_5+  \
# What is your tester ID? (Given to you by instru...
# 1                                                            True
# 2                                                            True
# 3                                                            True
# 4                                                           False
# 5                                                           False
#
#                                                     angular_0_1  angular_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                          True        False
# 2                                                          True        False
# 3                                                          True        False
# 4                                                          True        False
# 5                                                          True        False
#
#                                                     angular_3_5  angular_5+
# What is your tester ID? (Given to you by instru...
# 1                                                         False       False
# 2                                                         False       False
# 3                                                         False       False
# 4                                                         False       False
# 5                                                         False       False
#
# [5 rows x 29 columns]

# %%
df["cicd_0_1"] = df["How many years of experience do you have working with CI/CD pipelines?"].str.contains("0-1", na=False)
df["cicd_1_2"] = df["How many years of experience do you have working with CI/CD pipelines?"].str.contains("1-2", na=False)
df["cicd_3_5"] = df["How many years of experience do you have working with CI/CD pipelines?"].str.contains("3-5", na=False)
df["cicd_5+"] = df["How many years of experience do you have working with CI/CD pipelines?"].str.contains("5+", na=False)

df = df.drop("How many years of experience do you have working with CI/CD pipelines?", axis=1)

df.head()
# Out:
#                                                    How many years of experience of you have working with NX Workspace?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                                 0-1
# 2                                                                                                 0-1
# 3                                                                                                 0-1
# 4                                                                                                 0-1
# 5                                                                                                 0-1
#
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     deploy_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                 True
# 4                                                                 True
# 5                                                                False
#
#                                                     k8s_deploy_works  ...  \
# What is your tester ID? (Given to you by instru...                    ...
# 1                                                              False  ...
# 2                                                               True  ...
# 3                                                              False  ...
# 4                                                               True  ...
# 5                                                              False  ...
#
#                                                     kubernetes_3_5  \
# What is your tester ID? (Given to you by instru...
# 1                                                            False
# 2                                                             True
# 3                                                             True
# 4                                                            False
# 5                                                            False
#
#                                                     kubernetes_5+  \
# What is your tester ID? (Given to you by instru...
# 1                                                            True
# 2                                                            True
# 3                                                            True
# 4                                                           False
# 5                                                           False
#
#                                                     angular_0_1  angular_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                          True        False
# 2                                                          True        False
# 3                                                          True        False
# 4                                                          True        False
# 5                                                          True        False
#
#                                                     angular_3_5  angular_5+  \
# What is your tester ID? (Given to you by instru...
# 1                                                         False       False
# 2                                                         False       False
# 3                                                         False       False
# 4                                                         False       False
# 5                                                         False       False
#
#                                                     cicd_0_1  cicd_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                      False     False
# 2                                                      False      True
# 3                                                      False      True
# 4                                                       True     False
# 5                                                       True     False
#
#                                                     cicd_3_5  cicd_5+
# What is your tester ID? (Given to you by instru...
# 1                                                      False     True
# 2                                                      False    False
# 3                                                      False    False
# 4                                                      False    False
# 5                                                      False    False
#
# [5 rows x 32 columns]

# %%
df["nx_0_1"] = df["How many years of experience of you have working with NX Workspace?"].str.contains("0-1", na=False)
df["nx_1_2"] = df["How many years of experience of you have working with NX Workspace?"].str.contains("1-2", na=False)
df["nx_3_5"] = df["How many years of experience of you have working with NX Workspace?"].str.contains("3-5", na=False)
df["nx_5+"] = df["How many years of experience of you have working with NX Workspace?"].str.contains("5+", na=False)

df = df.drop("How many years of experience of you have working with NX Workspace?", axis=1)

df.head()
# Out:
#                                                    Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?  \
# What is your tester ID? (Given to you by instru...
# 1                                                   The agent did not set up the environment prope...
# 2                                                   The AI tried to repeatedly use wrong versions ...
# 3                                                   Good for basic outline of code structure. Not ...
# 4                                                   It worked pretty since I didn't code at all. I...
# 5                                                   without prior experience or time to accomodate...
#
#                                                    What time is it now at the beginning of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                               9:19
# 2                                                                                              10:27
# 3                                                                                              10:58
# 4                                                                                              11:01
# 5                                                                                              12:55
#
#                                                    What time is it now at the end of the test?  \
# What is your tester ID? (Given to you by instru...
# 1                                                                                        10:04
# 2                                                                                        11:12
# 3                                                                                        11:44
# 4                                                                                        11:45
# 5                                                                                        13:40
#
#                                                     cicd_runs_on_commit  \
# What is your tester ID? (Given to you by instru...
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4                                                                  True
# 5                                                                  True
#
#                                                     test_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                               True
# 4                                                               True
# 5                                                              False
#
#                                                     build_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                True
# 2                                                                True
# 3                                                                True
# 4                                                                True
# 5                                                               False
#
#                                                     docker_image_push_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                     False
# 2                                                                      True
# 3                                                                     False
# 4                                                                      True
# 5                                                                     False
#
#                                                     deploy_stage_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                                False
# 2                                                                 True
# 3                                                                 True
# 4                                                                 True
# 5                                                                False
#
#                                                     k8s_deploy_works  \
# What is your tester ID? (Given to you by instru...
# 1                                                              False
# 2                                                               True
# 3                                                              False
# 4                                                               True
# 5                                                              False
#
#                                                     pod_log_error_free  ...  \
# What is your tester ID? (Given to you by instru...                      ...
# 1                                                                False  ...
# 2                                                                 True  ...
# 3                                                                False  ...
# 4                                                                 True  ...
# 5                                                                False  ...
#
#                                                     angular_3_5  angular_5+  \
# What is your tester ID? (Given to you by instru...
# 1                                                         False       False
# 2                                                         False       False
# 3                                                         False       False
# 4                                                         False       False
# 5                                                         False       False
#
#                                                     cicd_0_1  cicd_1_2  \
# What is your tester ID? (Given to you by instru...
# 1                                                      False     False
# 2                                                      False      True
# 3                                                      False      True
# 4                                                       True     False
# 5                                                       True     False
#
#                                                     cicd_3_5  cicd_5+  nx_0_1  \
# What is your tester ID? (Given to you by instru...
# 1                                                      False     True    True
# 2                                                      False    False    True
# 3                                                      False    False    True
# 4                                                      False    False    True
# 5                                                      False    False    True
#
#                                                     nx_1_2  nx_3_5  nx_5+
# What is your tester ID? (Given to you by instru...
# 1                                                    False   False  False
# 2                                                    False   False  False
# 3                                                    False   False  False
# 4                                                    False   False  False
# 5                                                    False   False  False
#
# [5 rows x 35 columns]

# %%
df = df.rename(columns={"Describe your experience with the AI-assisted IDE. What worked well? What did not? Did the AI show unexpected or unproductive behavior? Did it work surprisingly well?": "free_text_feedback"})
df.index.names = ['tester_id']
df["test_duration_minutes"] = df.apply(lambda x: (datetime.strptime(x["What time is it now at the end of the test?"], "%H:%M")-datetime.strptime(x["What time is it now at the beginning of the test?"], "%H:%M")).total_seconds()/60, axis=1)
df = df.drop(["What time is it now at the beginning of the test?", "What time is it now at the end of the test?"], axis=1)
df.head()
# Out:
#                                           free_text_feedback  \
# tester_id
# 1          The agent did not set up the environment prope...
# 2          The AI tried to repeatedly use wrong versions ...
# 3          Good for basic outline of code structure. Not ...
# 4          It worked pretty since I didn't code at all. I...
# 5          without prior experience or time to accomodate...
#
#            cicd_runs_on_commit  test_stage_works  build_stage_works  \
# tester_id
# 1                        False             False               True
# 2                         True              True               True
# 3                         True              True               True
# 4                         True              True               True
# 5                         True             False              False
#
#            docker_image_push_works  deploy_stage_works  k8s_deploy_works  \
# tester_id
# 1                            False               False             False
# 2                             True                True              True
# 3                            False                True             False
# 4                             True                True              True
# 5                            False               False             False
#
#            pod_log_error_free  experience_excellent  experience_good  ...  \
# tester_id                                                             ...
# 1                       False                 False            False  ...
# 2                        True                 False             True  ...
# 3                       False                 False            False  ...
# 4                        True                 False             True  ...
# 5                       False                 False            False  ...
#
#            angular_5+  cicd_0_1  cicd_1_2  cicd_3_5  cicd_5+  nx_0_1  nx_1_2  \
# tester_id
# 1               False     False     False     False     True    True   False
# 2               False     False      True     False    False    True   False
# 3               False     False      True     False    False    True   False
# 4               False      True     False     False    False    True   False
# 5               False      True     False     False    False    True   False
#
#            nx_3_5  nx_5+  test_duration_minutes
# tester_id
# 1           False  False                   45.0
# 2           False  False                   45.0
# 3           False  False                   46.0
# 4           False  False                   44.0
# 5           False  False                   45.0
#
# [5 rows x 34 columns]

# %%
df["prompt_logs_filename"] = "prompt_logs_tester_" + df.index.astype(str).str.zfill(2) + ".json"
df.head()
# Out:
#                                           free_text_feedback  \
# tester_id
# 1          The agent did not set up the environment prope...
# 2          The AI tried to repeatedly use wrong versions ...
# 3          Good for basic outline of code structure. Not ...
# 4          It worked pretty since I didn't code at all. I...
# 5          without prior experience or time to accomodate...
#
#            cicd_runs_on_commit  test_stage_works  build_stage_works  \
# tester_id
# 1                        False             False               True
# 2                         True              True               True
# 3                         True              True               True
# 4                         True              True               True
# 5                         True             False              False
#
#            docker_image_push_works  deploy_stage_works  k8s_deploy_works  \
# tester_id
# 1                            False               False             False
# 2                             True                True              True
# 3                            False                True             False
# 4                             True                True              True
# 5                            False               False             False
#
#            pod_log_error_free  experience_excellent  experience_good  ...  \
# tester_id                                                             ...
# 1                       False                 False            False  ...
# 2                        True                 False             True  ...
# 3                       False                 False            False  ...
# 4                        True                 False             True  ...
# 5                       False                 False            False  ...
#
#            cicd_0_1  cicd_1_2  cicd_3_5  cicd_5+  nx_0_1  nx_1_2  nx_3_5  \
# tester_id
# 1             False     False     False     True    True   False   False
# 2             False      True     False    False    True   False   False
# 3             False      True     False    False    True   False   False
# 4              True     False     False    False    True   False   False
# 5              True     False     False    False    True   False   False
#
#            nx_5+  test_duration_minutes        prompt_logs_filename
# tester_id
# 1          False                   45.0  prompt_logs_tester_01.json
# 2          False                   45.0  prompt_logs_tester_02.json
# 3          False                   46.0  prompt_logs_tester_03.json
# 4          False                   44.0  prompt_logs_tester_04.json
# 5          False                   45.0  prompt_logs_tester_05.json
#
# [5 rows x 35 columns]

# %%
def calculate_token_usage(row):

    with open(f"data/user_study/{row['prompt_logs_filename']}") as f:
        data = json.load(f)

    total_prompt_tokens = 0
    total_completion_tokens = 0
    total_tokens = 0

    # Walk through prompts
    for prompt in data.get("prompts", []):
        log_count = prompt.get("logCount", 1)

        for log in prompt.get("logs", []):
            usage = log.get("metadata", {}).get("usage", {})
            prompt_tokens = usage.get("prompt_tokens", 0)
            completion_tokens = usage.get("completion_tokens", 0)
            total_log_tokens = usage.get("total_tokens", 0)

            # Multiply by logCount to account for multiple logs
            total_prompt_tokens += prompt_tokens
            total_completion_tokens += completion_tokens
            total_tokens += total_log_tokens
    
    row["total_prompts"] = len(data.get("prompts", []))
    row["total_prompt_tokens"] = total_prompt_tokens
    row["total_completion_tokens"] = total_completion_tokens
    row["total_tokens"] = total_tokens
    
    return row

df = df.apply(lambda row: calculate_token_usage(row), axis=1)
df = df.drop("prompt_logs_filename", axis=1)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 32
#      28     row["total_tokens"] = total_tokens
#      30     return row
# ---> 32 df = df.apply(lambda row: calculate_token_usage(row), axis=1)
#      33 df = df.drop("prompt_logs_filename", axis=1)
#      34 df.head(10)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[12], line 32, in <lambda>(row)
#      28     row["total_tokens"] = total_tokens
#      30     return row
# ---> 32 df = df.apply(lambda row: calculate_token_usage(row), axis=1)
#      33 df = df.drop("prompt_logs_filename", axis=1)
#      34 df.head(10)
#
# Cell In[12], line 4, in calculate_token_usage(row)
#       1 def calculate_token_usage(row):
#       3     with open(f"data/user_study/{row['prompt_logs_filename']}") as f:
# ----> 4         data = json.load(f)
#       6     total_prompt_tokens = 0
#       7     total_completion_tokens = 0
#
# NameError: name 'json' is not defined
